# %% [markdown]
# <a href="https://colab.research.google.com/github/BaberFaisal/Pandas_Practice/blob/main/Pandas__Pratice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

data = {
    'EmployeeID': [101, 102, 103, 104, 105, 106],
    'Name': ['Faisal', 'Sara', 'Ali', 'Zainab', 'Bilal', 'Hina'],
    'Department': ['IT', 'HR', 'IT', 'Finance', 'HR', 'Finance'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Age': [25, 28, 24, 30, None, 27],
    'Salary': [70000, 80000, 72000, 90000, 78000, None],
    'JoiningDate': [
        '2022-05-15', '2021-11-01', '2023-01-10',
        '2020-08-24', '2022-12-01', '2021-03-15'
    ],
    'City': ['Karachi', 'Lahore', 'Karachi', 'Islamabad', 'Lahore', 'Islamabad'],
    'PerformanceScore': [8.5, 9.2, 7.8, 8.9, 9.0, 8.1],
    'Bonus': [5000, 6000, 4000, 8000, 5500, 7000]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
df.tail(3)
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
df.shape
# Out:
# (6, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        6 non-null      int64
#  1   Name              6 non-null      object
#  2   Department        6 non-null      object
#  3   Gender            6 non-null      object
#  4   Age               5 non-null      float64
#  5   Salary            5 non-null      float64
#  6   JoiningDate       6 non-null      object
#  7   City              6 non-null      object
#  8   PerformanceScore  6 non-null      float64
#  9   Bonus             6 non-null      int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 612.0+ bytes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.describe()
# Out:
#        EmployeeID        Age        Salary  PerformanceScore        Bonus
# count    6.000000   5.000000      5.000000          6.000000     6.000000
# mean   103.500000  26.800000  78000.000000          8.583333  5916.666667
# std      1.870829   2.387467   7874.007874          0.549242  1428.869017
# min    101.000000  24.000000  70000.000000          7.800000  4000.000000
# 25%    102.250000  25.000000  72000.000000          8.200000  5125.000000
# 50%    103.500000  27.000000  78000.000000          8.700000  5750.000000
# 75%    104.750000  28.000000  80000.000000          8.975000  6750.000000
# max    106.000000  30.000000  90000.000000          9.200000  8000.000000

# %%
# multiple columns
df[["Name", "Salary"]]
# Out:
#      Name   Salary
# 0  Faisal  70000.0
# 1    Sara  80000.0
# 2     Ali  72000.0
# 3  Zainab  90000.0
# 4   Bilal  78000.0
# 5    Hina      NaN

# %%
# select rows
df.iloc[0]
# Out:
# EmployeeID                 101
# Name                    Faisal
# Department                  IT
# Gender                    Male
# Age                       25.0
# Salary                 70000.0
# JoiningDate         2022-05-15
# City                   Karachi
# PerformanceScore           8.5
# Bonus                     5000
# Name: 0, dtype: object

# %%
df.iloc[0:2]
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate     City  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15  Karachi
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01   Lahore
#
#    PerformanceScore  Bonus
# 0               8.5   5000
# 1               9.2   6000

# %%
df.iloc[0:3:2]
# Out:
#    EmployeeID    Name Department Gender   Age   Salary JoiningDate     City  \
# 0         101  Faisal         IT   Male  25.0  70000.0  2022-05-15  Karachi
# 2         103     Ali         IT   Male  24.0  72000.0  2023-01-10  Karachi
#
#    PerformanceScore  Bonus
# 0               8.5   5000
# 2               7.8   4000

# %%
#Using loc by label
df.loc[0]
# Out:
# EmployeeID                 101
# Name                    Faisal
# Department                  IT
# Gender                    Male
# Age                       25.0
# Salary                 70000.0
# JoiningDate         2022-05-15
# City                   Karachi
# PerformanceScore           8.5
# Bonus                     5000
# Name: 0, dtype: object

# %%
df.loc[0:2] #(inclusive)
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate     City  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15  Karachi
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01   Lahore
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10  Karachi
#
#    PerformanceScore  Bonus
# 0               8.5   5000
# 1               9.2   6000
# 2               7.8   4000

# %%
#select both rows and columns
df.loc[0, "Name"]
# Out:
# 'Faisal'

# %%
df.loc[0:1, "Name"]
# Out:
# 0    Faisal
# 1      Sara
# Name: Name, dtype: object

# %%
df.loc[0:1, ["Name","Age"]]
# Out:
#      Name   Age
# 0  Faisal  25.0
# 1    Sara  28.0

# %%
df[df["Age"]> 23]
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 5  Islamabad               8.1   7000

# %%
df[df["Name"] == "Faisal"]
# Out:
#    EmployeeID    Name Department Gender   Age   Salary JoiningDate     City  \
# 0         101  Faisal         IT   Male  25.0  70000.0  2022-05-15  Karachi
#
#    PerformanceScore  Bonus
# 0               8.5   5000

# %%
df[(df["Age"]>29) & (df["Salary"] > 8000)]
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
#
#         City  PerformanceScore  Bonus
# 3  Islamabad               8.9   8000

# %%
# isin() for Membership
df[df["Name"].isin(["Faisal", "Sara"])]
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate     City  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15  Karachi
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01   Lahore
#
#    PerformanceScore  Bonus
# 0               8.5   5000
# 1               9.2   6000

# %%
# Query
df.query("Age > 23 and Name == 'Faisal'") # careful
# Out:
#    EmployeeID    Name Department Gender   Age   Salary JoiningDate     City  \
# 0         101  Faisal         IT   Male  25.0  70000.0  2022-05-15  Karachi
#
#    PerformanceScore  Bonus
# 0               8.5   5000

# %%
# .at and .iat (Fast Accessors)
#df.at[row_label, column_label]
#df.iat[row_index, column_index]

df.at[0, "Name"]
# Out:
# 'Faisal'

# %%
df.iat[0,1]
# Out:
# 'Faisal'

# %%
# Null
df.isnull()
# Out:
#    EmployeeID   Name  Department  Gender    Age  Salary  JoiningDate   City  \
# 0       False  False       False   False  False   False        False  False
# 1       False  False       False   False  False   False        False  False
# 2       False  False       False   False  False   False        False  False
# 3       False  False       False   False  False   False        False  False
# 4       False  False       False   False   True   False        False  False
# 5       False  False       False   False  False    True        False  False
#
#    PerformanceScore  Bonus
# 0             False  False
# 1             False  False
# 2             False  False
# 3             False  False
# 4             False  False
# 5             False  False

# %%
df.isnull().sum()
# Out:
# EmployeeID          0
# Name                0
# Department          0
# Gender              0
# Age                 1
# Salary              1
# JoiningDate         0
# City                0
# PerformanceScore    0
# Bonus               0
# dtype: int64

# %%
df.notnull()
# Out:
#    EmployeeID  Name  Department  Gender    Age  Salary  JoiningDate  City  \
# 0        True  True        True    True   True    True         True  True
# 1        True  True        True    True   True    True         True  True
# 2        True  True        True    True   True    True         True  True
# 3        True  True        True    True   True    True         True  True
# 4        True  True        True    True  False    True         True  True
# 5        True  True        True    True   True   False         True  True
#
#    PerformanceScore  Bonus
# 0              True   True
# 1              True   True
# 2              True   True
# 3              True   True
# 4              True   True
# 5              True   True

# %%
# Drop
df.dropna() # drop rows with any missing values
df.dropna(axis=1) # drop columns with any missing values
# Out:
#    EmployeeID    Name Department  Gender JoiningDate       City  \
# 0         101  Faisal         IT    Male  2022-05-15    Karachi
# 1         102    Sara         HR  Female  2021-11-01     Lahore
# 2         103     Ali         IT    Male  2023-01-10    Karachi
# 3         104  Zainab    Finance  Female  2020-08-24  Islamabad
# 4         105   Bilal         HR    Male  2022-12-01     Lahore
# 5         106    Hina    Finance  Female  2021-03-15  Islamabad
#
#    PerformanceScore  Bonus
# 0               8.5   5000
# 1               9.2   6000
# 2               7.8   4000
# 3               8.9   8000
# 4               9.0   5500
# 5               8.1   7000

# %%
# Drop
df.dropna(how="all") # drop rows where all values are missing
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
# Drop rows if a specific column is missing
df.dropna(subset=["Salary"])
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500

# %%
# Filling Missing Values
df.fillna(0)
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   0.0  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      0.0  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
df.fillna("Unknown")
# Out:
#    EmployeeID    Name Department  Gender      Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male     25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female     28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male     24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female     30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male  Unknown  78000.0  2022-12-01
# 5         106    Hina    Finance  Female     27.0  Unknown  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
df["Salary"].fillna(df["Salary"].mean())
# Out:
# 0    70000.0
# 1    80000.0
# 2    72000.0
# 3    90000.0
# 4    78000.0
# 5    78000.0
# Name: Salary, dtype: float64

# %%
#Replacing Values
df.replace("N/A", None)
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
df["Gender"].replace({'Male':'M', 'Female': 'F'})
# Out:
# 0    M
# 1    F
# 2    M
# 3    F
# 4    M
# 5    F
# Name: Gender, dtype: object

# %%
# Rename Columns
df.rename(columns = {"old":"new"} )
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
df.columns = [col.lower() for col in df.columns] # see the structure

# %%
df
# Out:
#    employeeid    name department  gender   age   salary joiningdate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         city  performancescore  bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
# Remove duplicates
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#    employeeid    name department  gender   age   salary joiningdate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         city  performancescore  bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
# Convert Data Types
df["bonus"] = df["bonus"].astype(int)

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
# sort by columnn values
df.sort_values(by = "Salary", ascending = False )
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 3  Islamabad               8.9   8000
# 1     Lahore               9.2   6000
# 4     Lahore               9.0   5500
# 2    Karachi               7.8   4000
# 0    Karachi               8.5   5000
# 5  Islamabad               8.1   7000

# %%
# sort multiole columns
df.sort_values(by = ["Salary", "Bonus"])
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 2    Karachi               7.8   4000
# 4     Lahore               9.0   5500
# 1     Lahore               9.2   6000
# 3  Islamabad               8.9   8000
# 5  Islamabad               8.1   7000

# %%
# sort by index
df.sort_index()
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
# setting and resetting index
df.set_index("EmployeeID")
# Out:
#               Name Department  Gender   Age   Salary JoiningDate       City  \
# EmployeeID
# 101         Faisal         IT    Male  25.0  70000.0  2022-05-15    Karachi
# 102           Sara         HR  Female  28.0  80000.0  2021-11-01     Lahore
# 103            Ali         IT    Male  24.0  72000.0  2023-01-10    Karachi
# 104         Zainab    Finance  Female  30.0  90000.0  2020-08-24  Islamabad
# 105          Bilal         HR    Male   NaN  78000.0  2022-12-01     Lahore
# 106           Hina    Finance  Female  27.0      NaN  2021-03-15  Islamabad
#
#             PerformanceScore  Bonus
# EmployeeID
# 101                      8.5   5000
# 102                      9.2   6000
# 103                      7.8   4000
# 104                      8.9   8000
# 105                      9.0   5500
# 106                      8.1   7000

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#    index  EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0      0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1      1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2      2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3      3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4      4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5      5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
df = df.drop(columns = ["index"])

# %%
df
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus
# 0    Karachi               8.5   5000
# 1     Lahore               9.2   6000
# 2    Karachi               7.8   4000
# 3  Islamabad               8.9   8000
# 4     Lahore               9.0   5500
# 5  Islamabad               8.1   7000

# %%
# Basic Maths
df["total"] = df["Salary"] + df["Bonus"]

# %%
df
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus    total
# 0    Karachi               8.5   5000  75000.0
# 1     Lahore               9.2   6000  86000.0
# 2    Karachi               7.8   4000  76000.0
# 3  Islamabad               8.9   8000  98000.0
# 4     Lahore               9.0   5500  83500.0
# 5  Islamabad               8.1   7000      NaN

# %%
# Applying custom functions
df["Name Length"] = df["Name"].apply(len)

# %%
df
# Out:
#    EmployeeID    Name Department  Gender   Age   Salary JoiningDate  \
# 0         101  Faisal         IT    Male  25.0  70000.0  2022-05-15
# 1         102    Sara         HR  Female  28.0  80000.0  2021-11-01
# 2         103     Ali         IT    Male  24.0  72000.0  2023-01-10
# 3         104  Zainab    Finance  Female  30.0  90000.0  2020-08-24
# 4         105   Bilal         HR    Male   NaN  78000.0  2022-12-01
# 5         106    Hina    Finance  Female  27.0      NaN  2021-03-15
#
#         City  PerformanceScore  Bonus    total  Name Length
# 0    Karachi               8.5   5000  75000.0            6
# 1     Lahore               9.2   6000  86000.0            4
# 2    Karachi               7.8   4000  76000.0            3
# 3  Islamabad               8.9   8000  98000.0            6
# 4     Lahore               9.0   5500  83500.0            5
# 5  Islamabad               8.1   7000      NaN            4

# %%
# column wise summary
df.mean(numeric_only=True) # important numeric_only=True
# Out:
# EmployeeID            103.500000
# Age                    26.800000
# Salary              78000.000000
# PerformanceScore        8.583333
# Bonus                5916.666667
# total               83700.000000
# Name Length             4.666667
# dtype: float64

# %%
df["Age"].std()
# Out:
# 2.3874672772626644

# %%
# count values
df["Department"].value_counts() # important
# Out:
# Department
# IT         2
# HR         2
# Finance    2
# Name: count, dtype: int64

# %%
df["City"].unique()
# Out:
# array(['Karachi', 'Lahore', 'Islamabad'], dtype=object)

# %%
df["City"].nunique()
# Out:
# 3

# %%
# goup by
# what is average salary by department
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    90000.0
# HR         79000.0
# IT         71000.0
# Name: Salary, dtype: float64

# %%
df.groupby(["Department", "Gender"])["Salary"].mean()
# Out:
# Department  Gender
# Finance     Female    90000.0
# HR          Female    80000.0
#             Male      78000.0
# IT          Male      71000.0
# Name: Salary, dtype: float64

# %%
"""
AGGREGATION FUNCTIONS
Function	Purpose
mean()	Average
sum()	Total
count()	Number of entries
min() / max()	Min / Max
std()	Standard deviation
agg()	Multiple functions

"""
# Out:
# '\nAGGREGATION FUNCTIONS\nFunction\tPurpose\nmean()\tAverage\nsum()\tTotal\ncount()\tNumber of entries\nmin() / max()\tMin / Max\nstd()\tStandard deviation\nagg()\tMultiple functions\n\n'

# %%
# Multiple Aggregations with agg()
df.groupby("Department")["Salary"].agg(["mean","max", "min"])
# Out:
#                mean      max      min
# Department
# Finance     90000.0  90000.0  90000.0
# HR          79000.0  80000.0  78000.0
# IT          71000.0  72000.0  70000.0

# %%
# count items
df["Department"].value_counts() # flat count
# Out:
# Department
# IT         2
# HR         2
# Finance    2
# Name: count, dtype: int64

# %%
df.groupby("Department").size()
# Out:
# Department
# Finance    2
# HR         2
# IT         2
# dtype: int64
